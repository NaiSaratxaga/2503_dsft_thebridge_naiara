# %% [markdown]
# ## Análisis de Datos Meteorológicos con una API Pública
# Obtener datos del clima de una ciudad usando la API de Open-Meteo (https://open-meteo.com/) y analizar la temperatura.

# %% [markdown]
# * Haz una petición a la API para que devuelva el pronóstico de las temperaturas para una semana en Bilbao. El parámetro correspondiente es `temperature_2m` además de la latitud y la longitud.
# * Procesa la respuesta en formato JSON para obtener dos listas: una con la lista de temperaturas y otra con las fechas-horas correspondientes.
# * Crea un DataFrame con esas dos columnas: `Hora` y `Temperatura`
# * Elige la gráfica adecuada y visualiza el pronóstico de temperaturas.

# %% [markdown]
# Para crear la variable `Hora` del DataFrame puedes introducir directamente la lista que se obtiene del campo `data["hourly"]["time"]` o procesar esa lista mediante el siguiente código:
#
# `hours = pd.date_range(start=lista_de_horas, periods=len(temps), freq="H")`

# %%
import requests


# Coordenadas de Madrid
latitude = 40.4168
longitude = -3.7038


url = f"https://api.open-meteo.com/v1/forecast?"  # Aquí vienen el resto de los parámetros


# URL base de la API con los parámetros de latitud, longitud y temperatura
url = f"https://api.open-meteo.com/v1/forecast"
params = {
    "latitude": 43.2630,   # Latitud de Bilbao
    "longitude": -2.9350,  # Longitud de Bilbao
    "hourly": "temperature_2m",  # Obtener temperatura por hora
    "timezone": "Europe/Madrid"  # Ajustar la zona horaria
}

# Realizar la petición GET a la API
response = requests.get(url, params=params)

# Verificar si la solicitud fue exitosa (código 200)
if response.status_code == 200:
    data = response.json()  # Convertir la respuesta en formato JSON
    print(data)  # Imprimir la respuesta completa para ver la estructura
else:
    print(f"Error en la solicitud: {response.status_code}")
# Out:
# {'latitude': 43.26, 'longitude': -2.9300003, 'generationtime_ms': 0.05984306335449219, 'utc_offset_seconds': 3600, 'timezone': 'Europe/Madrid', 'timezone_abbreviation': 'GMT+1', 'elevation': 24.0, 'hourly_units': {'time': 'iso8601', 'temperature_2m': '°C'}, 'hourly': {'time': ['2025-03-27T00:00', '2025-03-27T01:00', '2025-03-27T02:00', '2025-03-27T03:00', '2025-03-27T04:00', '2025-03-27T05:00', '2025-03-27T06:00', '2025-03-27T07:00', '2025-03-27T08:00', '2025-03-27T09:00', '2025-03-27T10:00', '2025-03-27T11:00', '2025-03-27T12:00', '2025-03-27T13:00', '2025-03-27T14:00', '2025-03-27T15:00', '2025-03-27T16:00', '2025-03-27T17:00', '2025-03-27T18:00', '2025-03-27T19:00', '2025-03-27T20:00', '2025-03-27T21:00', '2025-03-27T22:00', '2025-03-27T23:00', '2025-03-28T00:00', '2025-03-28T01:00', '2025-03-28T02:00', '2025-03-28T03:00', '2025-03-28T04:00', '2025-03-28T05:00', '2025-03-28T06:00', '2025-03-28T07:00', '2025-03-28T08:00', '2025-03-28T09:00', '2025-03-28T10:00', '2025-03-28T11:00', '2025-03-28T12:00', '2025-03-28T13:00', '2025-03-28T14:00', '2025-03-28T15:00', '2025-03-28T16:00', '2025-03-28T17:00', '2025-03-28T18:00', '2025-03-28T19:00', '2025-03-28T20:00', '2025-03-28T21:00', '2025-03-28T22:00', '2025-03-28T23:00', '2025-03-29T00:00', '2025-03-29T01:00', '2025-03-29T02:00', '2025-03-29T03:00', '2025-03-29T04:00', '2025-03-
# {'latitude': 43.26,
#  'longitude': -2.9300003,
#  'generationtime_ms': 0.05984306335449219,
#  'utc_offset_seconds': 3600,
#  'timezone': 'Europe/Madrid',
#  'timezone_abbreviation': 'GMT+1',
#  'elevation': 24.0,
#  'hourly_units': {'time': 'iso8601', 'temperature_2m': '°C'},
#  'hourly': {'time': ['2025-03-27T00:00',
#    '2025-03-27T01:00',
#    '2025-03-27T02:00',
#    '2025-03-27T03:00',
#    '2025-03-27T04:00',
#    '2025-03-27T05:00',
#    '2025-03-27T06:00',
#    '2025-03-27T07:00',
#    '2025-03-27T08:00',
#    '2025-03-27T09:00',
#    '2025-03-27T10:00',
#    '2025-03-27T11:00',
#    '2025-03-27T12:00',
#    '2025-03-27T13:00',
#    '2025-03-27T14:00',
#    '2025-03-27T15:00',
#    '2025-03-27T16:00',
#    '2025-03-27T17:00',
#    '2025-03-27T18:00',
#    '2025-03-27T19:00',
#    '2025-03-27T20:00',
#    '2025-03-27T21:00',
#    '2025-03-27T22:00',
#    '2025-03-27T23:00',
#    '2025-03-28T00:00',
#    '2025-03-28T01:00',
#    '2025-03-28T02:00',
#    '2025-03-28T03:00',
#    '2025-03-28T04:00',
#    '2025-03-28T05:00',
#    '2025-03-28T06:00',
#    '2025-03-28T07:00',
#    '2025-03-28T08:00',
#    '2025-03-28T09:00',
#    '2025-03-28T10:00',
#    '2025-03-28T11:00',
#    '2025-03-28T12:00',
#    '2025-03-28T13:00',
#    '2025-03-28T14:00',
#    '2025-03-28T15:00',
#    '2025-03-28T16:00',
#    '2025-03-28T17:00',
#    '2025-03-28T18:00',
#    '2025-03-28T19:00',
#    '2025-03-28T20:00',
#    '2025-03-28T21:00',
#    '2025-03-28T22:00',
#    '2025-03-28T23:00',
#    '2025-03-29T00:00',
#    '2025-03-29T01:00',
#    '2025-03-29T02:00',
#    '2025-03-29T03:00',
#    '2025-03-29T04:00',
#    '2025-03-29T05:00',
#    '2025-03-29T06:00',
#    '2025-03-29T07:00',
#    '2025-03-29T08:00',
#    '2025-03-29T09:00',
#    '2025-03-29T10:00',
#    '2025-03-29T11:00',
#    '2025-03-29T12:00',
#    '2025-03-29T13:00',
#    '2025-03-29T14:00',
#    '2025-03-29T15:00',
#    '2025-03-29T16:00',
#    '2025-03-29T17:00',
#    '2025-03-29T18:00',
#    '2025-03-29T19:00',
#    '2025-03-29T20:00',
#    '2025-03-29T21:00',
#    '2025-03-29T22:00',
#    '2025-03-29T23:00',
#    '2025-03-30T00:00',
#    '2025-03-30T01:00',
#    '2025-03-30T02:00',
#    '2025-03-30T03:00',
#    '2025-03-30T04:00',
#    '2025-03-30T05:00',
#    '2025-03-30T06:00',
#    '2025-03-30T07:00',
#    '2025-03-30T08:00',
#    '2025-03-30T09:00',
#    '2025-03-30T10:00',
#    '2025-03-30T11:00',
#    '2025-03-30T12:00',
#    '2025-03-30T13:00',
#    '2025-03-30T14:00',
#    '2025-03-30T15:00',
#    '2025-03-30T16:00',
#    '2025-03-30T17:00',
#    '2025-03-30T18:00',
#    '2025-03-30T19:00',
#    '2025-03-30T20:00',
#    '2025-03-30T21:00',
#    '2025-03-30T22:00',
#    '2025-03-30T23:00',
#    '2025-03-31T00:00',
#    '2025-03-31T01:00',
#    '2025-03-31T02:00',
#    '2025-03-31T03:00',
#    '2025-03-31T04:00',
#    '2025-03-31T05:00',
#    '2025-03-31T06:00',
#    '2025-03-31T07:00',
#    '2025-03-31T08:00',
#    '2025-03-31T09:00',
#    '2025-03-31T10:00',
#    '2025-03-31T11:00',
#    '2025-03-31T12:00',
#    '2025-03-31T13:00',
#    '2025-03-31T14:00',
#    '2025-03-31T15:00',
#    '2025-03-31T16:00',
#    '2025-03-31T17:00',
#    '2025-03-31T18:00',
#    '2025-03-31T19:00',
#    '2025-03-31T20:00',
#    '2025-03-31T21:00',
#    '2025-03-31T22:00',
#    '2025-03-31T23:00',
#    '2025-04-01T00:00',
#    '2025-04-01T01:00',
#    '2025-04-01T02:00',
#    '2025-04-01T03:00',
#    '2025-04-01T04:00',
#    '2025-04-01T05:00',
#    '2025-04-01T06:00',
#    '2025-04-01T07:00',
#    '2025-04-01T08:00',
#    '2025-04-01T09:00',
#    '2025-04-01T10:00',
#    '2025-04-01T11:00',
#    '2025-04-01T12:00',
#    '2025-04-01T13:00',
#    '2025-04-01T14:00',
#    '2025-04-01T15:00',
#    '2025-04-01T16:00',
#    '2025-04-01T17:00',
#    '2025-04-01T18:00',
#    '2025-04-01T19:00',
#    '2025-04-01T20:00',
#    '2025-04-01T21:00',
#    '2025-04-01T22:00',
#    '2025-04-01T23:00',
#    '2025-04-02T00:00',
#    '2025-04-02T01:00',
#    '2025-04-02T02:00',
#    '2025-04-02T03:00',
#    '2025-04-02T04:00',
#    '2025-04-02T05:00',
#    '2025-04-02T06:00',
#    '2025-04-02T07:00',
#    '2025-04-02T08:00',
#    '2025-04-02T09:00',
#    '2025-04-02T10:00',
#    '2025-04-02T11:00',
#    '2025-04-02T12:00',
#    '2025-04-02T13:00',
#    '2025-04-02T14:00',
#    '2025-04-02T15:00',
#    '2025-04-02T16:00',
#    '2025-04-02T17:00',
#    '2025-04-02T18:00',
#    '2025-04-02T19:00',
#    '2025-04-02T20:00',
#    '2025-04-02T21:00',
#    '2025-04-02T22:00',
#    '2025-04-02T23:00'],
#   'temperature_2m': [11.2,
#    10.7,
#    10.7,
#    10.9,
#    10.6,
#    10.7,
#    10.3,
#    10.4,
#    10.9,
#    11.3,
#    11.6,
#    12.1,
#    12.4,
#    13.3,
#    13.1,
#    14.0,
#    13.7,
#    13.9,
#    13.9,
#    13.7,
#    13.1,
#    12.8,
#    13.0,
#    12.8,
#    12.5,
#    12.0,
#    11.7,
#    11.0,
#    11.5,
#    11.5,
#    11.4,
#    11.8,
#    11.9,
#    12.7,
#    13.2,
#    14.2,
#    14.7,
#    15.2,
#    15.9,
#    15.7,
#    15.0,
#    15.0,
#    14.7,
#    14.4,
#    13.7,
#    13.1,
#    13.2,
#    13.2,
#    13.0,
#    13.1,
#    12.7,
#    12.6,
#    12.2,
#    12.1,
#    12.0,
#    11.7,
#    11.8,
#    12.5,
#    13.5,
#    13.1,
#    12.9,
#    13.4,
#    13.5,
#    13.3,
#    13.4,
#    13.1,
#    12.6,
#    11.8,
#    10.7,
#    10.0,
#    9.6,
#    9.2,
#    8.6,
#    7.8,
#    7.2,
#    6.6,
#    6.2,
#    5.9,
#    5.8,
#    5.4,
#    5.7,
#    8.0,
#    11.0,
#    12.9,
#    14.0,
#    14.7,
#    14.9,
#    15.0,
#    14.6,
#    13.9,
#    13.1,
#    12.1,
#    10.5,
#    9.3,
#    8.3,
#    7.5,
#    7.0,
#    6.6,
#    6.4,
#    6.4,
#    6.6,
#    6.6,
#    6.3,
#    5.8,
#    6.2,
#    8.6,
#    11.8,
#    13.9,
#    16.2,
#    17.4,
#    18.6,
#    19.6,
#    20.1,
#    19.9,
#    19.1,
#    17.9,
#    16.1,
#    14.0,
#    12.4,
#    11.6,
#    11.2,
#    10.9,
#    10.4,
#    10.0,
#    9.6,
#    9.4,
#    9.2,
#    9.1,
#    11.8,
#    15.4,
#    18.5,
#    20.6,
#    22.3,
#    23.5,
#    24.6,
#    25.2,
#    25.3,
#    24.6,
#    23.3,
#    21.7,
#    19.4,
#    16.8,
#    14.6,
#    13.3,
#    12.4,
#    11.8,
#    11.5,
#    11.4,
#    11.3,
#    10.5,
#    9.5,
#    9.8,
#    12.2,
#    15.7,
#    18.8,
#    20.8,
#    22.3,
#    23.5,
#    24.5,
#    25.3,
#    25.3,
#    24.3,
#    22.5,
#    20.5,
#    18.2,
#    15.7,
#    13.7,
#    12.6]}}

# %%
 # Extraer listas de fechas y temperaturas
horas = data["hourly"]["time"]  # Lista de fechas y horas
temperaturas = data["hourly"]["temperature_2m"]  # Lista de temperaturas
    
    # Imprimir las listas
print("Horas:", horas[:5])  # Mostrar solo los primeros 5 valores
print("Temperaturas:", temperaturas[:5])
# Out:
# Horas: ['2025-03-27T00:00', '2025-03-27T01:00', '2025-03-27T02:00', '2025-03-27T03:00', '2025-03-27T04:00']
# Temperaturas: [11.2, 10.7, 10.7, 10.9, 10.6]

# %%
# Crea un DataFrame con esas dos columnas: `Hora` y `Temperatura`

# %%
import pandas as pd

# DataFrame con las listas extraídas
df = pd.DataFrame({"Hora": horas, "Temperatura": temperaturas})

# Convertir la columna 'Hora' a formato de fecha y hora
df["Hora"] = pd.to_datetime(df["Hora"])

# Mostrar las primeras filas del DataFrame
df.head()
# Out:
#                  Hora  Temperatura
# 0 2025-03-27 00:00:00         11.2
# 1 2025-03-27 01:00:00         10.7
# 2 2025-03-27 02:00:00         10.7
# 3 2025-03-27 03:00:00         10.9
# 4 2025-03-27 04:00:00         10.6

# %%
# Elige la gráfica adecuada y visualiza el pronóstico de temperaturas.

import matplotlib.pyplot as plt

# Crear la gráfica
plt.figure(figsize=(12, 6))  # Tamaño de la figura
plt.plot(df["Hora"], df["Temperatura"], marker="o", linestyle="-", color="b", label="Temperatura (°C)")

# Configuración de la gráfica
plt.xlabel("Fecha y Hora")
plt.ylabel("Temperatura (°C)")
plt.title("Pronóstico de Temperaturas en Bilbao")
plt.xticks(rotation=45)  
plt.grid(True, linestyle="--", alpha=0.6)  # Agregar una cuadrícula
plt.legend()

# Mostrar la gráfica
plt.show()
