# %% [markdown]
# ## Ejercicios de Matplotlib

# %% [markdown]
# 1. Importa pyplot, numpy y pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# 2. Sabemos que podemos pintar gráficas de dos formas: la figura incluye los ejes o teniendo figura y ejes por separado.
#
# Usando solo una figura, usa numpy para los valores del eje X entre 0 y 5.
#
# Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5).
#
# Elige la precisión en el eje X que desees.

# %%
# Crear valores del eje X entre 0 y 5 con precisión
x = np.linspace(0, 5, 100)

# Definir las ecuaciones de las rectas
y1 = 3 * x        # Recta con pendiente positiva (pasa por (0,0))
y2 = -3 * x - 5   # Recta con pendiente negativa (pasa por (0,-5))

# Con esto pintamos las 2 gráficas
# Crear la figura con dos subgráficos
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 fila, 2 columnas

# Gráfico de la izquierda (recta positiva)
axes[0].plot(x, y1, color='purple', label="y = 3x")
axes[0].set_title("RECTA POSITIVA")
axes[0].set_xlabel("X")
axes[0].set_ylabel("Y")
axes[0].axhline(0, color='red', linewidth=0.5)  # Línea del eje X
axes[0].axvline(0, color='red', linewidth=0.5)  # Línea del eje Y
axes[0].legend()
axes[0].grid()

# Gráfico de la derecha (recta negativa)
axes[1].plot(x, y2, color='green', label="y = -3x - 5")
axes[1].set_title("RECTA NEGATIVA")
axes[1].set_xlabel("X")
axes[1].axhline(0, color='red', linewidth=0.5)
axes[1].axvline(0, color='red', linewidth=0.5)
axes[1].legend()
axes[1].grid()


plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Fija el eje X entre 0 y 5 y el eje Y entre -15 y 15

# %%
axes[0].set_xlim(0, 5)  # Fijar límites en X
axes[0].set_ylim(-15, 15)  # Fijar límites en Y
# Out:
# (-15.0, 15.0)

# %%
# Crear valores del eje X entre 0 y 5 con precisión
x = np.linspace(0, 5, 100)

# Definir las ecuaciones de las rectas
y1 = 3 * x        # Recta con pendiente positiva (pasa por (0,0))
y2 = -3 * x - 5   # Recta con pendiente negativa (pasa por (0,-5))

# Con esto pintamos las 2 gráficas
# Crear la figura con dos subgráficos
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 fila, 2 columnas

# Gráfico de la izquierda (recta positiva)
axes[0].plot(x, y1, color='purple', label="y = 3x")
axes[0].set_title("RECTA POSITIVA")
axes[0].set_xlabel("X")
axes[0].set_ylabel("Y")
axes[0].set_xlim(0, 5)  # Fijar límites en X
axes[0].set_ylim(-15, 15)  # Fijar límites en Y
axes[0].axhline(0, color='red', linewidth=0.5)  # Línea del eje X
axes[0].axvline(0, color='red', linewidth=0.5)  # Línea del eje Y
axes[0].legend()
axes[0].grid()

# Gráfico de la derecha (recta negativa)
axes[1].plot(x, y2, color='green', label="y = -3x - 5")
axes[1].set_title("RECTA NEGATIVA")
axes[1].set_xlabel("X")
axes[0].set_xlim(0, 5)  # Fijar límites en X
axes[0].set_ylim(-15, 15)  # Fijar límites en Y
axes[1].axhline(0, color='red', linewidth=0.5)
axes[1].axvline(0, color='red', linewidth=0.5)
axes[1].legend()
axes[1].grid()


plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Llama al eje X "eje X", al eje Y "eje Y" y pon de títulos "recta sube" y "recta baja". Muestra dos etiquetas de ejeX pero solo una de eje Y.

# %%
# Crear valores del eje X entre 0 y 5 con precisión
x = np.linspace(0, 5, 100)

# Definir las ecuaciones de las rectas
y1 = 3 * x        # Recta con pendiente positiva (pasa por (0,0))
y2 = -3 * x - 5   # Recta con pendiente negativa (pasa por (0,-5))

# Con esto pintamos las 2 gráficas
# Crear la figura con dos subgráficos
# se usa subplots cunado necesitas 2 gráficos dentrro de una misma figura
# axes son los subgráficos, es un array de objetos. axes[0] es el primer gráfico y axes[1] segundo gráfico
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 fila, 2 columnas

# Gráfico de la izquierda (recta positiva)
axes[0].plot(x, y1, color='purple', label="y = 3x")
axes[0].set_title("RECTA SUBE")
axes[0].set_xlabel("eje X")
axes[0].set_ylabel("eje Y")
axes[0].set_xlim(0, 5)  # Fijar límites en X
axes[0].set_ylim(-15, 15)  # Fijar límites en Y
axes[0].axhline(0, color='red', linewidth=0.5)  # Línea del eje X
axes[0].axvline(0, color='red', linewidth=0.5)  # Línea del eje Y
axes[0].legend()
axes[0].grid()

# Gráfico de la derecha (recta negativa)
axes[1].plot(x, y2, color='green', label="y = -3x - 5")
axes[1].set_title("RECTA BAJA")
axes[1].set_xlabel("eje X")
axes[0].set_xlim(0, 5)  # Fijar límites en X
axes[0].set_ylim(-15, 15)  # Fijar límites en Y
axes[1].axhline(0, color='red', linewidth=0.5)
axes[1].axvline(0, color='red', linewidth=0.5)
axes[1].legend()
axes[1].grid()


plt.tight_layout()
plt.show()

# %% [markdown]
# 5. Usando una figura Y EJES POR SEPARADO, usa numpy para los valores del eje X entre 0 y 5. Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5). Elige la precisión en el eje X que desees.

# %%
# Crear valores del eje X entre 0 y 5 con precisión
x = np.linspace(0, 5, 100)

# Definir las ecuaciones de las rectas
y1 = 3 * x        # Recta con pendiente positiva (pasa por (0,0))
y2 = -3 * x - 5   # Recta con pendiente negativa (pasa por (0,-5))

# Crea una figura, que es el "lienzo" donde se dibujarán los gráficos
fig = plt.figure(figsize=(10, 4)) # Define el tamaño de la figura (ancho y alto)

# Crear el primer eje (izquierda)
ax1 = fig.add_axes([0.1, 0.1, 0.38, 0.8])  # [left, bottom, width, height]
ax1.plot(x, y1, color='purple', label="y = 3x")
ax1.set_title("recta sube")  
ax1.set_xlabel("eje X")
ax1.set_ylabel("eje Y")  # Solo este eje tiene la etiqueta Y
ax1.axhline(0, color='red', linewidth=0.5)
ax1.axvline(0, color='red', linewidth=0.5)
ax1.set_xlim(0, 5)
ax1.set_ylim(-15, 15)
ax1.legend()
ax1.grid()

# Crear el segundo eje (derecha)
ax2 = fig.add_axes([0.55, 0.1, 0.38, 0.8])  # [left, bottom, width, height]
ax2.plot(x, y2, color='green', label="y = -3x - 5")
ax2.set_title("recta baja")
ax2.set_xlabel("eje X")
ax2.axhline(0, color='red', linewidth=0.5)
ax2.axvline(0, color='red', linewidth=0.5)
ax2.set_xlim(0, 5)
ax2.set_ylim(-15, 15)
ax2.legend()
ax2.grid()

plt.show()

# %% [markdown]
# 6. Crea una lista de coordenadas X: 20, 22, 24, 26, 28
# Crea una lista de coordenadas Y: 5, 15, -5, 20, 5
# Usa un gráfico de barras colocadas en X con alturas Y

# %%
# Datos
x = [20, 22, 24, 26, 28]
y = [5, 15, -5, 20, 5]

# Crear gráfico de barras con varios atributos
plt.bar(x, y, 
        color='orange',       # Color de las barras
        width=0.6,            # Ancho de las barra
        edgecolor='black',    # Color del borde de las barras
       )

# Añadir etiquetas y título
plt.xlabel("Coordenadas X")
plt.ylabel("Altura (Y)")
plt.title("Gráfico de Barras")

# Mostrar gráfico
plt.show()

# %% [markdown]
# 7. Crea un gráfico de barras. Pintamos la altura de un grupo de amigos, cada barra representa a una persona. Ana mide 160 cm, Luis mide 180 cm, Pedro mide 175 cm, Sofía mide 190 cm, Carmen mide 170 cm. Las barras serán verdes.
# Consejo: si no vas a tener que manipular especialmente los ejes, es más sencillo dejarlos dentro de la figura.

# %%
# Datos de nombres y alturas
nombres = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen'] # eje x
alturas = [160, 180, 175, 190, 170] # eje y

# Crear gráfico de barras
plt.bar(nombres, alturas, color='green')

# Añadir etiquetas y título
plt.xlabel("AMIGOS")
plt.ylabel("Altura (cm)")
plt.title("Alturas de los amigos")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 8. Cambia el tamaño de la figura a (3,5)

# %%
# Datos
nombres = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Crear gráfico de barras con el tamaño de la figura de 3x5 pulgadas
plt.figure(figsize=(3, 5))  # Cambiar el tamaño de la figura a (3, 5)

# Crear el gráfico de barras
plt.bar(nombres, alturas, color='green')

# Añadir etiquetas y título
plt.xlabel("Amigos")
plt.ylabel("Altura (cm)")
plt.title("Alturas de los amigos")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 9. Basándote en el gráfico anterior, borra la escala del eje Y (ya aparece en la altura)
# Pista: cuando plt.yticks() recibe una lista vacía no pinta el eje Y

# %%
# Datos
nombres = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Crear gráfico de barras con el tamaño de la figura de 3x5 pulgadas
plt.figure(figsize=(3, 5))  

# Eliminar la escala del eje Y
plt.yticks([])  # Al pasar una lista vacía, se eliminan las marcas del eje Y

# Crear el gráfico de barras
plt.bar(nombres, alturas, color='green')

# Añadir etiquetas y título
plt.xlabel("Amigos")
plt.ylabel("Altura (cm)")
plt.title("Alturas de los amigos")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 10. Prueba a hacer el gráfico con las barras en horizontal.

# %%
# Datos
nombres = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Crear gráfico de barras horizontales con el tamaño de la figura de 3x5 pulgadas
plt.figure(figsize=(3, 5))  # Cambiar el tamaño de la figura a (3, 5)

# Crear el gráfico de barras horizontal
plt.barh(nombres, alturas, color='green')

# Eliminar la escala del eje Y
plt.xticks([])  # Al pasar una lista vacía, se eliminan las marcas del eje X

# Añadir etiquetas y título
plt.xlabel("Altura (cm)")
plt.ylabel("Amigos")
plt.title("Alturas de los amigos")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 11. Prueba a invertir los ejes con ax.invert_axis()
# Necesitarás tener los ejes disponibles fuera de la figura

# %%
# Datos
nombres = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]


# Crear la figura y los ejes por separado
fig, ax = plt.subplots(figsize=(3, 5))  # Crear figura y ejes con tamaño (3, 5)

# Crear el gráfico de barras horizontal
ax.barh(nombres, alturas, color='green')

# Eliminar la escala del eje X
ax.set_xticks([])  # Al pasar una lista vacía, se eliminan las marcas del eje X

# Invertir los ejes
ax.invert_xaxis()  # Esto invierte el eje X (barras van hacia la izquierda)

# Añadir etiquetas y título
ax.set_xlabel("Altura (cm)")
ax.set_ylabel("Amigos")
ax.set_title("Alturas de los amigos")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 12. En el último gráfico, cambia el estilo a 'dark_background'

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# Si lo hago de esta forma, me cambia el background de todos los gráficos que tengo.

""" import matplotlib.pyplot as plt

# Datos
nombres = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Usar el estilo 'dark_background' solo para este gráfico
with plt.style.context('dark_background'):
    # Crear la figura y los ejes por separado
    fig, ax = plt.subplots(figsize=(3, 5))  # Crear figura y ejes con tamaño (3, 5)

    # Crear el gráfico de barras horizontal
    ax.barh(nombres, alturas, color='green')

    # Eliminar la escala del eje X
    ax.set_xticks([])  # Al pasar una lista vacía, se eliminan las marcas del eje X

    # Invertir los ejes
    ax.invert_xaxis()  # Esto invierte el eje X (barras van hacia la izquierda)

    # Añadir etiquetas y título
    ax.set_xlabel("Altura (cm)")
    ax.set_ylabel("Amigos")
    ax.set_title("Alturas de los amigos")

    # Mostrar el gráfico
    plt.show()

 """
# Out:
# ' import matplotlib.pyplot as plt\n\n# Datos\nnombres = [\'Ana\', \'Luis\', \'Pedro\', \'Sofía\', \'Carmen\']\nalturas = [160, 180, 175, 190, 170]\n\n# Usar el estilo \'dark_background\' solo para este gráfico\nwith plt.style.context(\'dark_background\'):\n    # Crear la figura y los ejes por separado\n    fig, ax = plt.subplots(figsize=(3, 5))  # Crear figura y ejes con tamaño (3, 5)\n\n    # Crear el gráfico de barras horizontal\n    ax.barh(nombres, alturas, color=\'green\')\n\n    # Eliminar la escala del eje X\n    ax.set_xticks([])  # Al pasar una lista vacía, se eliminan las marcas del eje X\n\n    # Invertir los ejes\n    ax.invert_xaxis()  # Esto invierte el eje X (barras van hacia la izquierda)\n\n    # Añadir etiquetas y título\n    ax.set_xlabel("Altura (cm)")\n    ax.set_ylabel("Amigos")\n    ax.set_title("Alturas de los amigos")\n\n    # Mostrar el gráfico\n    plt.show()\n\n '

# %%
# He mirado en internet como hacer paara que no me cambie el background

# Datos
nombres = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Crear la figura y los ejes por separado
fig, ax = plt.subplots(figsize=(3, 5))  # Crear figura y ejes con tamaño (3, 5)

# Cambiar fondo y color de la gráfica solo para este gráfico
fig.patch.set_facecolor('black')  # Fondo negro para la figura
ax.set_facecolor('black')  # Fondo negro para los ejes
ax.spines['top'].set_color('white')  # Bordes de la gráfica en blanco
ax.spines['right'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.tick_params(axis='x', colors='white')  # Marcas del eje X en blanco
ax.tick_params(axis='y', colors='white')  # Marcas del eje Y en blanco
ax.xaxis.label.set_color('white')  # Etiqueta del eje X en blanco
ax.yaxis.label.set_color('white')  # Etiqueta del eje Y en blanco
ax.title.set_color('white')  # Título en blanco

# Crear el gráfico de barras horizontal
ax.barh(nombres, alturas, color='green')

# Añadir etiquetas y título
ax.set_xlabel("Altura (cm)")
ax.set_ylabel("Amigos")
ax.set_title("Alturas de los amigos")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 13. Vamos a introducir pandas. Crea un DataFrame con las columnas "Year" de valores 2015, 2016, 2017, 2018, 2019 y la columna "Sold_items_A" de valores 1000, 3500, 4000, 5500, 7000

# %%
# Crear el DataFrame con los datos proporcionados
data = {
    'Year': [2015, 2016, 2017, 2018, 2019],
    'Sold_items_A': [1000, 3500, 4000, 5500, 7000]
}

df = pd.DataFrame(data)


df
# Out:
#    Year  Sold_items_A
# 0  2015          1000
# 1  2016          3500
# 2  2017          4000
# 3  2018          5500
# 4  2019          7000

# %% [markdown]
# 14. Ahora pintamos un gráfico de línea con las ventas respecto al año. Pon un título y etiquetas en los ejes.
# Cambia el estilo a 'seaborn-white'. La línea debe ser con rayas y verde.

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# Establecer el estilo a 'seaborn-white'
""" plt.style.use('seaborn-white') # Si pongo este estilo me da error, comprobar plt.style.available
"""
plt.style.use('seaborn-v0_8-whitegrid')

# Crear el gráfico de línea con los datos del DataFrame
plt.plot(df['Year'], df['Sold_items_A'], linestyle='--', color='green')

# Ajustar el eje X para que solo muestre años enteros
plt.xticks(df['Year'])  # Con esto forzamos a usar solo los años exactos del DataFrame

# Añadir título y etiquetas
plt.title("Ventas de artículos A por Año")
plt.xlabel("Año")
plt.ylabel("Ventas de artículos A")

plt.show()

# %% [markdown]
# 15. Otro departamento B ha vendido en esos años 2000, 3100, 5000, 4000, 6000 unidades. Incluye esa columna en el DataFrame y pinta en la misma gráfica las dos líneas. B es una línea punteada y roja. Muestra una leyenda abajo a la derecha.

# %%
# Crear el DataFrame con los datos de ventas
data = {
    'Year': [2015, 2016, 2017, 2018, 2019],
    'Sold_items_A': [1000, 3500, 4000, 5500, 7000],
    'Sold_items_B': [2000, 3100, 5000, 4000, 6000] # columna nueva
}

df = pd.DataFrame(data)

# Configurar el estilo
plt.style.use('seaborn-v0_8-whitegrid')

# Crear la figura y los ejes
fig, ax = plt.subplots()

# Ventas del Departamento A
ax.plot(df['Year'], df['Sold_items_A'], linestyle='--', color='green', label="Departamento A")

# Ventas del Departamento B
ax.plot(df['Year'], df['Sold_items_B'], linestyle=':', color='red', label="Departamento B")

# Añadir título y etiquetas
ax.set_title("Ventas de artículos por Año")
ax.set_xlabel("Año")
ax.set_ylabel("Ventas de artículos")

# Asegurar que solo aparecen los años del DataFrame en el eje X
ax.set_xticks(df['Year'])

# Agregar la leyenda abajo a la derecha
ax.legend(loc="lower right")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 16. Haz un scatter del departamento A usando __solo el DataFrame__.
# Pista: el propio DataFrame tiene un método plot.
# df.plot('columna X', 'columna Y', 'kind' = 'scatter)

# %%
# Crear el scatter plot desde el DataFrame con una etiqueta para la leyenda
ax = df.plot(x='Year', y='Sold_items_A', kind='scatter', color='blue', label="Ventas A")

# Forzar que solo se muestren los años exactos en el eje X
plt.xticks(df['Year'])

# Añadir título y etiquetas
plt.title("Ventas del Departamento A")
plt.xlabel("Año")
plt.ylabel("Unidades Vendidas")

# Mostrar la leyenda en la esquina inferior derecha
plt.legend(loc="lower right")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 17. Prueba a cambiar kind a 'pie'

# %%
# Crear el scatter plot desde el DataFrame 
ax = df.plot(x='Year', y='Sold_items_A', kind='pie', color='blue', label="Ventas A")

# Forzar que solo se muestren los años exactos en el eje X
plt.xticks(df['Year'])

# Añadir título y etiquetas
plt.title("Ventas del Departamento A")
plt.xlabel("Año")
plt.ylabel("Unidades Vendidas")

# Mostrar la leyenda en la esquina inferior derecha
plt.legend(loc="lower right")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# 18. Prueba a quitar la leyenda incluyendo legend igual a False, añade labels y quita la etiqueta en Y

# %%
# Crear el scatter plot sin leyenda (legend=False)
ax = df.plot(x='Year', y='Sold_items_A', kind='scatter', color='blue', label="Ventas A", legend=False)

# Forzar que solo se muestren los años exactos en el eje X
plt.xticks(df['Year'])

# Añadir título y etiquetas personalizadas
plt.title("Ventas del Departamento A")
ax.set_xlabel("Año")  # Etiqueta personalizada para el eje X
ax.set_ylabel("")     # Eliminar la etiqueta en el eje Y


plt.show()

# %% [markdown]
# 19. Vamos a pintar un histograma de unas alturas generadas aleatoriamente. Crea 300 alturas entre 150 y 190 cm.

# %%
# Generar 300 alturas aleatorias entre 150 y 190 cm
alturas = np.random.randint(150, 191, size=300)

# Pintar el histograma
plt.hist(alturas, bins=20, color='skyblue', edgecolor='black')

# Añadir título y etiquetas
plt.title("Distribución de Alturas")
plt.xlabel("Altura (cm)")
plt.ylabel("Frecuencia")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Pista: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html
