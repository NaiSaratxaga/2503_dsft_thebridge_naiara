# %% [markdown]
# # Ejercicios de Seaborn

# %%
# 1. Importa pandas, pyplot y seaborn

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
pokemon = pd.read_csv("data/pokemon.csv")
pokemon
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# 0         65     45      1      False
# 1         80     60      2      False
# 2        100     80      3      False
# 3         50     65      1      False
# 4         65     80      2      False
# ..       ...    ...    ...        ...
# 146       50     50      1      False
# 147       70     70      2      False
# 148      100     80      3      False
# 149       90    130      1       True
# 150      100    100      1      False
#
# [151 rows x 13 columns]

# %% [markdown]
# - Name: El nombre del Pokémon
# - Type1 y Type2 : Los tipos del pokemon, (principal y si tiene sesundario)
# - Total : Una suma de las estadísticas (HP, Attack, Defense, Special Attack, Special Defense, Speed) que representa el poder total del Pokémon.
# - Hp: Health Points, cantidad de vida del pokemon
# - Attack: Al poder de los ataques físicos del Pokémon.
# - Defense: Resistencia a los ataques físicos.
# - Sp. Atk: La fuerza de los ataques especiales.
# - Sp. Def: La resistencia del Pokémon a los ataques especiales.
# - Speed: La rapidez del Pokémon.
# - Stage: Etapa evolutiva.
# - Legendary: Indica si el Pokémon es legendario o no.

# %%
# 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          151 non-null    int64
#  1   Name       151 non-null    object
#  2   Type 1     151 non-null    object
#  3   Type 2     67 non-null     object
#  4   Total      151 non-null    int64
#  5   HP         151 non-null    int64
#  6   Attack     151 non-null    int64
#  7   Defense    151 non-null    int64
#  8   Sp. Atk    151 non-null    int64
#  9   Sp. Def    151 non-null    int64
#  10  Speed      151 non-null    int64
#  11  Stage      151 non-null    int64
#  12  Legendary  151 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 14.4+ KB

# %%
pokemon.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  151.000000  151.00000  151.000000  151.000000  151.000000  151.000000
# mean    76.000000  407.07947   64.211921   72.549669   68.225166   67.139073
# std     43.734045   99.74384   28.590117   26.596162   26.916704   28.534199
# min      1.000000  195.00000   10.000000    5.000000    5.000000   15.000000
# 25%     38.500000  320.00000   45.000000   51.000000   50.000000   45.000000
# 50%     76.000000  405.00000   60.000000   70.000000   65.000000   65.000000
# 75%    113.500000  490.00000   80.000000   90.000000   84.000000   87.500000
# max    151.000000  680.00000  250.000000  134.000000  180.000000  154.000000
#
#           Sp. Def       Speed       Stage
# count  151.000000  151.000000  151.000000
# mean    66.019868   68.933775    1.582781
# std     24.197926   26.746880    0.676832
# min     20.000000   15.000000    1.000000
# 25%     49.000000   46.500000    1.000000
# 50%     65.000000   70.000000    1.000000
# 75%     80.000000   90.000000    2.000000
# max    125.000000  140.000000    3.000000

# %% [markdown]
# - std:

# %%
# 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal
# Pasa el DataFrame como argumento del método en el parámetro llamado data
#--------------------------------------------------------------------------------------#
# Solo se pueden comparar dos variables numéricas
# Regresión lineal: la línea recta que mejor se ajusta a los datos.
# Si la línea de regresión sube hacia la derecha ➝ relación positiva (a más ataque, más defensa).
# Si la línea baja hacia la derecha ➝ relación negativa (a más ataque, menos defensa).
# Si la línea es casi horizontal ➝ no hay relación clara entre ataque y defensa.
plt.figure(figsize=(10, 6))

sns.lmplot(x="Attack", y="Defense", data=pokemon)
plt.grid()
plt.show()

# %%
# y = a*x + b
# 50 = a *40 + b

# %%
# 6. No queremos ver la línea recta de la regresión lineal.
# prueba a añadir fit_reg a falso

sns.lmplot(x="Attack", y="Defense", data=pokemon, fit_reg=False)
plt.grid()
plt.show()

# %%
# 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el hue sea el Stage

sns.lmplot(x="Attack", y="Defense", hue="Stage", data=pokemon, fit_reg=False)
plt.grid()
plt.show()

# %%
# 8. Limita el eje x entre 20 y 100
plt.figure(figsize=(10, 6))

sns.lmplot(x="Attack", y="Defense", hue="Stage", data=pokemon, fit_reg=False)

# Limitar el eje x entre 20 y 100
plt.xlim(20, 100)

plt.show()

# %%
# 9. Dibuja un diagrama de cajas con el dataframe

# Para el diagrama de cajas uso boxplot
plt.figure(figsize=(10, 9))

sns.boxplot(x="Attack", y="Defense", data=pokemon)

plt.show()

# %%
# Para el diagrama de cajas uso boxplot

plt.figure(figsize=(10, 9))
sns.boxplot(x="Stage", y="Defense", data=pokemon)

plt.show()

# %%
# 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

plt.figure(figsize=(10, 8))
# borramos las columans con drop.
pokemon = pokemon.drop(columns=["Total", "Stage", "Legendary"])

# creamos de nuevo el boxplot
sns.boxplot(x="HP", y="Attack", data=pokemon)

# Rotar las etiquetas del eje X
plt.xticks(rotation=45)

plt.show()

# %%
# 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame
# Ver los tipos únicos en la columna "Type 1"

num_types = pokemon["Type 1"].nunique() # Devuelve directamente la cantidad de tipos diferentes, un número entero.(si no necesitas ver cuales son, solo el número total)
print(f'Número de tipos diferentes en "Type 1": {num_types}')

print()

# Mostrar los nombres de los tipos
type_names = pokemon["Type 1"].unique() # Este método devuelve un array con los nombres únicos.
print(f'Los tipos diferentes en "Type 1" son: {type_names}')
# Out:
# Número de tipos diferentes en "Type 1": 15
#
# Los tipos diferentes en "Type 1" son: ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon']

# %%
# 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# Filtrar el DataFrame, uso isin.(devuelve un booleano que es True solo para las filas en las que el valor en "Type 1" es 'Grass', 'Fire' o 'Water'.))
pokemon_type = pokemon[pokemon["Type 1"].isin(["Grass", "Fire", "Water"])]

pokemon_type
# Out:
#        #        Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur  Grass    Poison   45      49       49       65       65
# 1      2     Ivysaur  Grass    Poison   60      62       63       80       80
# 2      3    Venusaur  Grass    Poison   80      82       83      100      100
# 3      4  Charmander   Fire       NaN   39      52       43       60       50
# 4      5  Charmeleon   Fire       NaN   58      64       58       80       65
# 5      6   Charizard   Fire    Flying   78      84       78      109       85
# 6      7    Squirtle  Water       NaN   44      48       65       50       64
# 7      8   Wartortle  Water       NaN   59      63       80       65       80
# 8      9   Blastoise  Water       NaN   79      83      100       85      105
# 36    37      Vulpix   Fire       NaN   38      41       40       50       65
# 37    38   Ninetales   Fire       NaN   73      76       75       81      100
# 42    43      Oddish  Grass    Poison   45      50       55       75       65
# 43    44       Gloom  Grass    Poison   60      65       70       85       75
# 44    45   Vileplume  Grass    Poison   75      80       85      110       90
# 53    54     Psyduck  Water       NaN   50      52       48       65       50
# 54    55     Golduck  Water       NaN   80      82       78       95       80
# 57    58   Growlithe   Fire       NaN   55      70       45       70       50
# 58    59    Arcanine   Fire       NaN   90     110       80      100       80
# 59    60     Poliwag  Water       NaN   40      50       40       40       40
# 60    61   Poliwhirl  Water       NaN   65      65       65       50       50
# 61    62   Poliwrath  Water  Fighting   90      95       95       70       90
# 68    69  Bellsprout  Grass    Poison   50      75       35       70       30
# 69    70  Weepinbell  Grass    Poison   65      90       50       85       45
# 70    71  Victreebel  Grass    Poison   80     105       65      100       70
# 71    72   Tentacool  Water    Poison   40      40       35       50      100
# 72    73  Tentacruel  Water    Poison   80      70       65       80      120
# 76    77      Ponyta   Fire       NaN   50      85       55       65       65
# 77    78    Rapidash   Fire       NaN   65     100       70       80       80
# 78    79    Slowpoke  Water   Psychic   90      65       65       40       40
# 79    80     Slowbro  Water   Psychic   95      75      110      100       80
# 85    86        Seel  Water       NaN   65      45       55       45       70
# 86    87     Dewgong  Water       Ice   90      70       80       70       95
# 89    90    Shellder  Water       NaN   30      65      100       45       25
# 90    91    Cloyster  Water       Ice   50      95      180       85       45
# 97    98      Krabby  Water       NaN   30     105       90       25       25
# 98    99     Kingler  Water       NaN   55     130      115       50       50
# 101  102   Exeggcute  Grass   Psychic   60      40       80       60       45
# 102  103   Exeggutor  Grass   Psychic   95      95       85      125       65
# 113  114     Tangela  Grass       NaN   65      55      115      100       40
# 115  116      Horsea  Water       NaN   30      40       70       70       25
# 116  117      Seadra  Water       NaN   55      65       95       95       45
# 117  118     Goldeen  Water       NaN   45      67       60       35       50
# 118  119     Seaking  Water       NaN   80      92       65       65       80
# 119  120      Staryu  Water       NaN   30      45       55       70       55
# 120  121     Starmie  Water   Psychic   60      75       85      100       85
# 125  126      Magmar   Fire       NaN   65      95       57      100       85
# 128  129    Magikarp  Water       NaN   20      10       55       15       20
# 129  130    Gyarados  Water    Flying   95     125       79       60      100
# 130  131      Lapras  Water       Ice  130      85       80       85       95
# 133  134    Vaporeon  Water       NaN  130      65       60      110       95
# 135  136     Flareon   Fire       NaN   65     130       60       95      110
# 145  146     Moltres   Fire    Flying   90     100       90      125       85
#
#      Speed
# 0       45
# 1       60
# 2       80
# 3       65
# 4       80
# 5      100
# 6       43
# 7       58
# 8       78
# 36      65
# 37     100
# 42      30
# 43      40
# 44      50
# 53      55
# 54      85
# 57      60
# 58      95
# 59      90
# 60      90
# 61      70
# 68      40
# 69      55
# 70      70
# 71      70
# 72     100
# 76      90
# 77     105
# 78      15
# 79      30
# 85      45
# 86      70
# 89      40
# 90      70
# 97      50
# 98      75
# 101     40
# 102     55
# 113     60
# 115     60
# 116     85
# 117     63
# 118     68
# 119     85
# 120    115
# 125     93
# 128     80
# 129     81
# 130     60
# 133     65
# 135     65
# 145     90

# %%
# 13. Usa un estilo 'whitegrid'
# Estilo 'whitegrid'

plt.figure(figsize=(10, 6))

sns.set_theme(
    style="whitegrid",        # Fondo blanco con cuadrícula
    palette="Set2",            # Paleta de colores 'Set2'
    #context="talk",            # Contexto más grande para presentaciones
    font="Arial",              # Fuente Arial
    #font_scale=1.2,            # Aumento en el tamaño de la fuente
    rc={"axes.titlesize": 16, "axes.labelsize": 14}  # Tamaño de títulos y etiquetas. Personalización avanzada de parámetros de Matplotlib.
)

# Crear un diagrama de cajas como ejemplo
sns.boxplot(x="Type 1", y="Attack", data=pokemon_type)


plt.show()

# %%
# 14. Pinta diagramas de violín con el DataFrame filtrado por los 3 tipos

plt.figure(figsize=(10, 6))
sns.violinplot(x="Type 1", y="Attack", data=pokemon_type, palette="Set2")


plt.show()
# Out:
# C:\Users\nsara\AppData\Local\Temp\ipykernel_1576\3263342131.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Type 1", y="Attack", data=pokemon_type, palette="Set2")

# %%
# 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

colores = ['#78C850', '#F08030', '#6890F0']

# %%
# 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)
plt.figure(figsize=(10, 6))
sns.violinplot(x="Type 1", y="Attack", data=pokemon_type, palette=colores)
# Out:
# C:\Users\nsara\AppData\Local\Temp\ipykernel_1576\2424364476.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Type 1", y="Attack", data=pokemon_type, palette=colores)
# <Axes: xlabel='Type 1', ylabel='Attack'>

# %%
# 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# Para ver esto, usamos el swarmplot.
# Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin


# Configurar el tamaño de la figura
plt.figure(figsize=(10, 6))

# Crear el swarmplot
sns.swarmplot(x="Type 1", y="Attack", data=pokemon_type, palette=colores)

plt.show()
# Out:
# C:\Users\nsara\AppData\Local\Temp\ipykernel_1576\3547055517.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="Type 1", y="Attack", data=pokemon_type, palette=colores)

# %%
# 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos. 
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9 en el swarmplot
# Pon un título con pyplot (como siempre)

# Configurar el tamaño de la figura
plt.figure(figsize=(10, 6))

sns.violinplot(x="Type 1", y="Attack", data=pokemon_type, palette=colores, inner=None, alpha=0.9)

# Sobreponer el swarmplot
sns.swarmplot(x="Type 1", y="Attack", data=pokemon_type, color="black", size=6)

plt.title("Distribución del Ataque por Tipo de Pokémon", fontsize=14, fontweight="bold")

plt.show()
# Out:
# C:\Users\nsara\AppData\Local\Temp\ipykernel_1576\997532363.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Type 1", y="Attack", data=pokemon_type, palette=colores, inner=None, alpha=0.9)

# %%
# 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
# Dado un DataFrame, melt recibe varios parámetros:
# * qué columnas del DataFrame se quedan igual
# * qué nombres de columnas del dataframe pasan a ser una columna nueva
# * cómo queremos llamar esas nuevas columnas

# Primero recuerda el Dataframe df_grass_fire_water con las primeras 5 filas

pokemon_type.head()

pokemon_extra=pokemon_type.iloc[:25,:]
pokemon_extra
# Out:
#      #        Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    1   Bulbasaur  Grass    Poison  45      49       49       65       65
# 1    2     Ivysaur  Grass    Poison  60      62       63       80       80
# 2    3    Venusaur  Grass    Poison  80      82       83      100      100
# 3    4  Charmander   Fire       NaN  39      52       43       60       50
# 4    5  Charmeleon   Fire       NaN  58      64       58       80       65
# 5    6   Charizard   Fire    Flying  78      84       78      109       85
# 6    7    Squirtle  Water       NaN  44      48       65       50       64
# 7    8   Wartortle  Water       NaN  59      63       80       65       80
# 8    9   Blastoise  Water       NaN  79      83      100       85      105
# 36  37      Vulpix   Fire       NaN  38      41       40       50       65
# 37  38   Ninetales   Fire       NaN  73      76       75       81      100
# 42  43      Oddish  Grass    Poison  45      50       55       75       65
# 43  44       Gloom  Grass    Poison  60      65       70       85       75
# 44  45   Vileplume  Grass    Poison  75      80       85      110       90
# 53  54     Psyduck  Water       NaN  50      52       48       65       50
# 54  55     Golduck  Water       NaN  80      82       78       95       80
# 57  58   Growlithe   Fire       NaN  55      70       45       70       50
# 58  59    Arcanine   Fire       NaN  90     110       80      100       80
# 59  60     Poliwag  Water       NaN  40      50       40       40       40
# 60  61   Poliwhirl  Water       NaN  65      65       65       50       50
# 61  62   Poliwrath  Water  Fighting  90      95       95       70       90
# 68  69  Bellsprout  Grass    Poison  50      75       35       70       30
# 69  70  Weepinbell  Grass    Poison  65      90       50       85       45
# 70  71  Victreebel  Grass    Poison  80     105       65      100       70
# 71  72   Tentacool  Water    Poison  40      40       35       50      100
#
#     Speed
# 0      45
# 1      60
# 2      80
# 3      65
# 4      80
# 5     100
# 6      43
# 7      58
# 8      78
# 36     65
# 37    100
# 42     30
# 43     40
# 44     50
# 53     55
# 54     85
# 57     60
# 58     95
# 59     90
# 60     90
# 61     70
# 68     40
# 69     55
# 70     70
# 71     70

# %%
# melt() convierte columnas en filas.
# * qué columnas del DataFrame se quedan igual
# name y type1 se mantienen
#* qué nombres de columnas del dataframe pasan a ser una columna nueva
# - New Column= HP, Attack,Defense, Sp.Attack,Sp.Def y Speed 
# Value= los valores numéricos
# * cómo queremos llamar esas nuevas columnas
# var_name='Stat',  # Nueva columna que contendrá los nombres de las columnas originales 
# value_name='Value'  # Nueva columna que contendrá los valores correspondientes

pokemon_extra = pokemon_extra.melt(id_vars=['Name', 'Type 1'], value_vars=['HP', 'Attack', 'Defense', 'Sp. Atk',   'Sp. Def', 'Speed'], var_name='New Column')
pokemon_extra
# Out:
#            Name Type 1 New Column  value
# 0     Bulbasaur  Grass         HP     45
# 1       Ivysaur  Grass         HP     60
# 2      Venusaur  Grass         HP     80
# 3    Charmander   Fire         HP     39
# 4    Charmeleon   Fire         HP     58
# ..          ...    ...        ...    ...
# 145   Poliwrath  Water      Speed     70
# 146  Bellsprout  Grass      Speed     40
# 147  Weepinbell  Grass      Speed     55
# 148  Victreebel  Grass      Speed     70
# 149   Tentacool  Water      Speed     70
#
# [150 rows x 4 columns]

# %%
# 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# Escribimos df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')

# %%
# 21. Pintamos el swarmplot con el melted y entendemos la información
plt.figure(figsize=(10, 6))

# swarmplot crea un gráfico de dispersión.
sns.swarmplot(data=pokemon_extra, x="New Column", y="value", hue="Type 1")

plt.legend(title="Tipo de Pokémon", loc='upper left', bbox_to_anchor=(1, 1))

# Título y etiquetas
plt.title("Distribución de Estadísticas de Pokémon por Tipo", fontsize=16)
plt.xlabel("Estadísticas", fontsize=12)
plt.ylabel("Valor de la Estadística", fontsize=12)
# Out:
# Text(80.75, 0.5, 'Valor de la Estadística')

# %%
# 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon

# Dodge en inglés es "esquivar", ¿qué diferencia ves?
# - "separa" los puntos de diferentes categorías dentro de una misma variable para que no se superpongan.
# - Si tienes varias categorías en el eje X (por ejemplo, diferentes tipos de Pokémon), los puntos de esas categorías se desplazan horizontalmente para evitar que se amontonen y se vean con claridad.

# Usando plt 
# fija el límite del eje Y entre 0 y 200
# fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

plt.figure(figsize=(10, 6))
sns.swarmplot(data=pokemon_extra, x="New Column", y="value", hue="Type 1", dodge=True)
pokemon_palette = ['#78C850', '#F08030', '#6890F0', '#A8B820', '#A040A0', '#F8D030'] 

plt.legend(title="Tipo de Pokémon", loc='upper left', bbox_to_anchor=(1, 1))

# Establecer límites en el eje Y entre 0 y 200
plt.ylim(0, 200)

# Título y etiquetas
plt.title("Distribución de Estadísticas de Pokémon por Tipo", fontsize=16)
plt.xlabel("Estadísticas", fontsize=12)
plt.ylabel("Valor de la Estadística", fontsize=12)
# Out:
# Text(80.75, 0.5, 'Valor de la Estadística')

# %%
# Observa que incluso usando Seaborn, usamos Pyplot para trabajar con los ejes, la leyenda y el tamaño
# Lo importante es que Seaborn y Pyplot conviven bien juntos

# %%
# 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
# Pista: las correlaciones se calculan con el método corr()
# Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %%
# Seleccionar solo las columnas numéricas, si no corr no funciona.
correlation_matrix = pokemon.select_dtypes(include=['number']).corr()

# annot= True, muestra los valores numéricos dentro de cada celda del heatmap.
# cmap='coolwarm', define el colormap (cmap) de la gráfica.
# fmt='.2f', Indica el formato de los números dentro de cada celda.
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Título del gráfico
plt.title("Matriz de Correlación del DataFrame", fontsize=16)


plt.show()

# %%
# ¿la correlación entre qué valores se encuentra?
# la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# Encuentra dos variables que veas que están fuertemente relacionadas según la correlación
# Si tuvieras una matriz de correlación muy grande y te cobrasen por cada dato que lees, ¿qué harías? (ML)

# %% [markdown]
# ### ¿la correlación entre qué valores se encuentra?
# - La correlación entre dos variables muestra el grado en el que ambas variables están relacionadas linealmente. La correlación en la matriz varía entre -1 y 1.
# En este caso, los valores están entre -0.05 y 1.00, lo que indica correlaciones desde muy débiles (cercanas a 0) hasta perfectas (1.00).
#
# ### la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# - La autocorrelación (cuando una variable se correlaciona consigo misma) siempre es 1.00.
# - La autocorrelación es de 1 (o muy cercana a 1) en la diagonal principal de la matriz de correlación, porque cualquier variable está perfectamente correlacionada consigo misma.
#
# ### Encuentra dos variables que veas que están fuertemente relacionadas según la correlación
# - Sp. Atk y Sp. Def tienen una correlación de 0.52, lo que indica una relación moderadamente fuerte.
#
# Attack y Defense tienen una correlación de 0.49, lo que sugiere que Pokémon con alto ataque suelen tener también alta defensa.
# ### Si tuvieras una matriz de correlación muy grande y te cobrasen por cada dato que lees, ¿qué harías? (ML)
# - Me centraría solo en las correlaciones fuertes y eliminaría aquellas que sean muy bajas o cercanas a cero, ya que no aportan información útil.

# %%
# 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

plt.figure(figsize=(10, 6))

# kde= True, activa la curva de densidad (KDE - Kernel Density Estimation).
# Esta curva suaviza el histograma para mostrar mejor la distribución de los datos.
# Es útil para ver si los datos siguen una distribución normal o si tienen sesgo.
sns.histplot(data=pokemon, x="Defense", bins=20, kde=True, color="skyblue")

# Etiquetas
plt.title("Histograma y Densidad de 'Defense'", fontsize=16)
plt.xlabel("Nivel de Defensa", fontsize=12)
plt.ylabel("Frecuencia", fontsize=12)


plt.show()

# Es ligeramente simétrica, es una distribución normal.
# La línea suaviza la forma del histograma y permite ver la distribución con más claridad.

# %%
# 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot
# Usa plt.xticks y gira las etiquetas


# Establecer el tamaño de la figura
plt.figure(figsize=(10, 6))

# Pintar el diagrama de barras para la columna 'Type 1'
# Muestra la frecuencia de ocurrencia de cada valor en la columna Type 1
sns.countplot(data=pokemon, x='Type 1', palette='Set2')

# Girar las etiquetas del eje X
plt.xticks(rotation=45)

# Añadir título y etiquetas
plt.title("Número de Pokémon por Tipo (Type 1)", fontsize=16)
plt.xlabel("Tipo de Pokémon", fontsize=12)
plt.ylabel("Cantidad de Pokémon", fontsize=12)


plt.show()

# La altura de cada barra indicará cuántos Pokémon de ese tipo primario existen en el dataset
# Out:
# C:\Users\nsara\AppData\Local\Temp\ipykernel_1576\3049263110.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=pokemon, x='Type 1', palette='Set2')

# %%
# 26. Usa catplot con el DataFrame original. Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios
# y divide los colores según el Type 2

# col='Legendary': Se crean dos subgráficos, uno para los Pokémon legendarios y otro para los no legendarios, basándose en el valor de la columna 'Legendary'.
sns.catplot( data=pokemon, x='Type 1', y='Defense', hue='Type 2',  col='Legendary').set_xticklabels(rotation=45)


plt.show()

# %%
# 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.
# Di un bin 2D donde caigan muchos puntos (ataque, defensa).


# Graficar la distribución de probabilidad 2D (curvas de nivel) para ataque y defensa
sns.kdeplot(data=pokemon, x='Attack', y='Defense', cmap='Blues', fill=True, levels=10)

# Añadir títulos y mostrar el gráfico
plt.title('Distribución de Probabilidad: Defensa vs. Ataque')
plt.xlabel('Ataque')
plt.ylabel('Defensa')
plt.show()

# %%
# 28. Pinta una distribución de probabilidad conjunta con jointplot, pintando la defensa respecto al ataque del DataFrame original

sns.jointplot(data=pokemon, x='Attack', y='Defense', kind='kde', cmap='Blues')

plt.show()
